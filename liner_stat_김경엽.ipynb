# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
olympics = pd.read_csv('../Data/athlete_events.csv')
olympics.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
print(olympics.isnull().sum())
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
# 올림픽 메달 결측치 처리
olympics['Medal'] = olympics['Medal'].fillna('DNW')

# %%
print(olympics.isnull().sum())
# Out:
# ID            0
# Name          0
# Sex           0
# Age        9474
# Height    60171
# Weight    62875
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal         0
# dtype: int64

# %%
# drop_duplicates() 중복값 제거

print(olympics.loc[:, ['NOC', 'Team']].drop_duplicates()['NOC'].value_counts().head())
# Out:
# NOC
# FRA    160
# USA     97
# GBR     96
# SWE     52
# NOR     46
# Name: count, dtype: int64

# %%
noc_country = pd.read_csv('../Data/noc_regions.csv')
noc_country.drop('notes', axis = 1 , inplace = True)
noc_country.rename(columns = {'region':'Country'}, inplace = True)

noc_country.head()
# Out:
#    NOC      Country
# 0  AFG  Afghanistan
# 1  AHO      Curacao
# 2  ALB      Albania
# 3  ALG      Algeria
# 4  AND      Andorra

# %%
# olympics 와 noc_country 의 noc 열을 기준으로 olympics 와 noc_country 의 값이 일치하는 행이 있는 경우 해당행 추가
# 만약 오른쪽 데이터프레임에 일치하는 값이 없다면, 해당 열은 NaN으로 채움.
olympics_merge = olympics.merge(noc_country,
                                left_on = 'NOC',
                                right_on = 'NOC',
                                how = 'left')

# %%
olympics_merge.loc[olympics_merge['Country'].isnull(),['NOC', 'Team']].drop_duplicates()
# Out:
#         NOC                      Team
# 580     SGP                 Singapore
# 680     FRG              West Germany
# 682     GDR              East Germany
# 6265    GDR            East Germany-1
# 6491    ROT  Refugee Olympic Athletes
# 10491   FRG            West Germany-2
# 12780   FRG            West Germany-1
# 12922   GDR            East Germany-2
# 46948   SGP              June Climene
# 64426   UNK                   Unknown
# 68412   TUV                    Tuvalu
# 73754   GDR            East Germany-3
# 86128   SGP                   Rika II
# 103350  FRG            West Germany-3
# 116164  SGP               Singapore-2
# 252591  SGP               Singapore-1

# %%
# np.where(조건, 'Singapore', olympics_merge['Country'])
# 조건이 True 이면 Sigaproe, False 이면 기존 Country 유지

olympics_merge['Country'] = np.where(olympics_merge['NOC']=='SGP', 'Singapore', olympics_merge['Country'])
olympics_merge['Country'] = np.where(olympics_merge['NOC']=='ROT', 'Refugee Olympic Athletes', olympics_merge['Country'])
olympics_merge['Country'] = np.where(olympics_merge['NOC']=='UNK', 'Unknown', olympics_merge['Country'])
olympics_merge['Country'] = np.where(olympics_merge['NOC']=='TUV', 'Tuvalu', olympics_merge['Country'])

# %%
olympics_merge
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 290771  135569                Andrzej ya   M  29.0   179.0    89.0
# 290772  135570                  Piotr ya   M  27.0   176.0    59.0
# 290773  135570                  Piotr ya   M  27.0   176.0    59.0
# 290774  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 290775  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 290771        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 290772          Poland  POL  2014 Winter  2014  Winter           Sochi
# 290773          Poland  POL  2014 Winter  2014  Winter           Sochi
# 290774          Poland  POL  1998 Winter  1998  Winter          Nagano
# 290775          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal  \
# 0          Basketball               Basketball Men's Basketball   DNW
# 1                Judo              Judo Men's Extra-Lightweight   DNW
# 2            Football                   Football Men's Football   DNW
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres   DNW
# ...               ...                                       ...   ...
# 290771           Luge                Luge Mixed (Men)'s Doubles   DNW
# 290772    Ski Jumping  Ski Jumping Men's Large Hill, Individual   DNW
# 290773    Ski Jumping        Ski Jumping Men's Large Hill, Team   DNW
# 290774      Bobsleigh                      Bobsleigh Men's Four   DNW
# 290775      Bobsleigh                      Bobsleigh Men's Four   DNW
#
#             Country
# 0             China
# 1             China
# 2           Denmark
# 3           Denmark
# 4       Netherlands
# ...             ...
# 290771       Poland
# 290772       Poland
# 290773       Poland
# 290774       Poland
# 290775       Poland
#
# [290776 rows x 16 columns]

# %%
olympics_merge.drop('Team', axis = 1, inplace = True)
olympics_merge.rename(columns = {'Country': 'Team'}, inplace = True)

# %%
olympics_merge
# Out:
#             ID                      Name Sex   Age  Height  Weight  NOC  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0  CHN
# 1            2                  A Lamusi   M  23.0   170.0    60.0  CHN
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED
# ...        ...                       ...  ..   ...     ...     ...  ...
# 290771  135569                Andrzej ya   M  29.0   179.0    89.0  POL
# 290772  135570                  Piotr ya   M  27.0   176.0    59.0  POL
# 290773  135570                  Piotr ya   M  27.0   176.0    59.0  POL
# 290774  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0  POL
# 290775  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0  POL
#
#               Games  Year  Season            City          Sport  \
# 0       1992 Summer  1992  Summer       Barcelona     Basketball
# 1       2012 Summer  2012  Summer          London           Judo
# 2       1920 Summer  1920  Summer       Antwerpen       Football
# 3       1900 Summer  1900  Summer           Paris     Tug-Of-War
# 4       1988 Winter  1988  Winter         Calgary  Speed Skating
# ...             ...   ...     ...             ...            ...
# 290771  1976 Winter  1976  Winter       Innsbruck           Luge
# 290772  2014 Winter  2014  Winter           Sochi    Ski Jumping
# 290773  2014 Winter  2014  Winter           Sochi    Ski Jumping
# 290774  1998 Winter  1998  Winter          Nagano      Bobsleigh
# 290775  2002 Winter  2002  Winter  Salt Lake City      Bobsleigh
#
#                                            Event Medal         Team
# 0                    Basketball Men's Basketball   DNW        China
# 1                   Judo Men's Extra-Lightweight   DNW        China
# 2                        Football Men's Football   DNW      Denmark
# 3                    Tug-Of-War Men's Tug-Of-War  Gold      Denmark
# 4               Speed Skating Women's 500 metres   DNW  Netherlands
# ...                                          ...   ...          ...
# 290771                Luge Mixed (Men)'s Doubles   DNW       Poland
# 290772  Ski Jumping Men's Large Hill, Individual   DNW       Poland
# 290773        Ski Jumping Men's Large Hill, Team   DNW       Poland
# 290774                      Bobsleigh Men's Four   DNW       Poland
# 290775                      Bobsleigh Men's Four   DNW       Poland
#
# [290776 rows x 15 columns]

# %%
w_gdp = pd.read_csv('../Data/w_gdp.csv', skiprows = 3)

# 불필요한 열 제거
w_gdp.drop(['Indicator Name', 'Indicator Code'], axis = 1, inplace = True)

# 열(column)들이 여러 연도의 GDP 데이터를 나타내고 있음.
# 데이터를 효율적으로 병합하기 위해 연도별 GDP 데이터를 단일 열로 변환해야 함.
w_gdp = pd.melt(w_gdp, id_vars = ['Country Name', 'Country Code'], var_name = 'Year', value_name = 'GDP')

# 'Year' 열을 숫자형 데이터로 변환
w_gdp['Year'] = pd.to_numeric(w_gdp['Year'])

w_gdp.head()
# Out:
#   Country Name Country Code  Year          GDP
# 0        Aruba          ABW  1960          NaN
# 1  Afghanistan          AFG  1960  537777811.0
# 2       Angola          AGO  1960          NaN
# 3      Albania          ALB  1960          NaN
# 4      Andorra          AND  1960          NaN

# %%
w_gdp[w_gdp['Country Code'] == 'USA']
w_gdp[w_gdp['Country Code'] == 'GER']
w_gdp[w_gdp['Country Code'] == 'CHN']
w_gdp[w_gdp['Country Code'] == 'GBR']
w_gdp[w_gdp['Country Code'] == 'FRA']
# Out:
#       Country Name Country Code  Year           GDP
# 75          France          FRA  1960  6.265147e+10
# 339         France          FRA  1961  6.834674e+10
# 603         France          FRA  1962  7.631378e+10
# 867         France          FRA  1963  8.555111e+10
# 1131        France          FRA  1964  9.490659e+10
# 1395        France          FRA  1965  1.021606e+11
# 1659        France          FRA  1966  1.105975e+11
# 1923        France          FRA  1967  1.194661e+11
# 2187        France          FRA  1968  1.298471e+11
# 2451        France          FRA  1969  1.407255e+11
# 2715        France          FRA  1970  1.489489e+11
# 2979        France          FRA  1971  1.665645e+11
# 3243        France          FRA  1972  2.042835e+11
# 3507        France          FRA  1973  2.653816e+11
# 3771        France          FRA  1974  2.865262e+11
# 4035        France          FRA  1975  3.620009e+11
# 4299        France          FRA  1976  3.734103e+11
# 4563        France          FRA  1977  4.114643e+11
# 4827        France          FRA  1978  5.081831e+11
# 5091        France          FRA  1979  6.158341e+11
# 5355        France          FRA  1980  7.035253e+11
# 5619        France          FRA  1981  6.175896e+11
# 5883        France          FRA  1982  5.868370e+11
# 6147        France          FRA  1983  5.618521e+11
# 6411        France          FRA  1984  5.326488e+11
# 6675        France          FRA  1985  5.551971e+11
# 6939        France          FRA  1986  7.745563e+11
# 7203        France          FRA  1987  9.383684e+11
# 7467        France          FRA  1988  1.023504e+12
# 7731        France          FRA  1989  1.030122e+12
# 7995        France          FRA  1990  1.275301e+12
# 8259        France          FRA  1991  1.275563e+12
# 8523        France          FRA  1992  1.408725e+12
# 8787        France          FRA  1993  1.330095e+12
# 9051        France          FRA  1994  1.401636e+12
# 9315        France          FRA  1995  1.609892e+12
# 9579        France          FRA  1996  1.614245e+12
# 9843        France          FRA  1997  1.460709e+12
# 10107       France          FRA  1998  1.510758e+12
# 10371       France          FRA  1999  1.500276e+12
# 10635       France          FRA  2000  1.368438e+12
# 10899       France          FRA  2001  1.382218e+12
# 11163       France          FRA  2002  1.500338e+12
# 11427       France          FRA  2003  1.848124e+12
# 11691       France          FRA  2004  2.124112e+12
# 11955       France          FRA  2005  2.203679e+12
# 12219       France          FRA  2006  2.325012e+12
# 12483       France          FRA  2007  2.663113e+12
# 12747       France          FRA  2008  2.923466e+12
# 13011       France          FRA  2009  2.693827e+12
# 13275       France          FRA  2010  2.646837e+12
# 13539       France          FRA  2011  2.862680e+12
# 13803       France          FRA  2012  2.681416e+12
# 14067       France          FRA  2013  2.808511e+12
# 14331       France          FRA  2014  2.849305e+12
# 14595       France          FRA  2015  2.433562e+12
# 14859       France          FRA  2016  2.465454e+12
# 15123       France          FRA  2017           NaN

# %%
w_gdp.isna().sum()
# Out:
# Country Name       0
# Country Code       0
# Year               0
# GDP             3805
# dtype: int64

# %%
olympics_merge_ccode = olympics_merge.merge(w_gdp[['Country Name', 'Country Code']].drop_duplicates(),
                                            left_on = 'Team',
                                            right_on = 'Country Name',
                                            how = 'left')

olympics_merge_ccode.drop('Country Name', axis = 1, inplace = True)

# Merge to get gdp too
olympics_merge_gdp = olympics_merge_ccode.merge(w_gdp,
                                                left_on = ['Country Code', 'Year'],
                                                right_on = ['Country Code', 'Year'],
                                                how = 'left')

olympics_merge_gdp.drop('Country Name', axis = 1, inplace = True)

# %%
olympics_merge_gdp
# Out:
#             ID                      Name Sex   Age  Height  Weight  NOC  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0  CHN
# 1            2                  A Lamusi   M  23.0   170.0    60.0  CHN
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED
# ...        ...                       ...  ..   ...     ...     ...  ...
# 290771  135569                Andrzej ya   M  29.0   179.0    89.0  POL
# 290772  135570                  Piotr ya   M  27.0   176.0    59.0  POL
# 290773  135570                  Piotr ya   M  27.0   176.0    59.0  POL
# 290774  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0  POL
# 290775  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0  POL
#
#               Games  Year  Season            City          Sport  \
# 0       1992 Summer  1992  Summer       Barcelona     Basketball
# 1       2012 Summer  2012  Summer          London           Judo
# 2       1920 Summer  1920  Summer       Antwerpen       Football
# 3       1900 Summer  1900  Summer           Paris     Tug-Of-War
# 4       1988 Winter  1988  Winter         Calgary  Speed Skating
# ...             ...   ...     ...             ...            ...
# 290771  1976 Winter  1976  Winter       Innsbruck           Luge
# 290772  2014 Winter  2014  Winter           Sochi    Ski Jumping
# 290773  2014 Winter  2014  Winter           Sochi    Ski Jumping
# 290774  1998 Winter  1998  Winter          Nagano      Bobsleigh
# 290775  2002 Winter  2002  Winter  Salt Lake City      Bobsleigh
#
#                                            Event Medal         Team  \
# 0                    Basketball Men's Basketball   DNW        China
# 1                   Judo Men's Extra-Lightweight   DNW        China
# 2                        Football Men's Football   DNW      Denmark
# 3                    Tug-Of-War Men's Tug-Of-War  Gold      Denmark
# 4               Speed Skating Women's 500 metres   DNW  Netherlands
# ...                                          ...   ...          ...
# 290771                Luge Mixed (Men)'s Doubles   DNW       Poland
# 290772  Ski Jumping Men's Large Hill, Individual   DNW       Poland
# 290773        Ski Jumping Men's Large Hill, Team   DNW       Poland
# 290774                      Bobsleigh Men's Four   DNW       Poland
# 290775                      Bobsleigh Men's Four   DNW       Poland
#
#        Country Code           GDP
# 0               CHN  4.269157e+11
# 1               CHN  8.560547e+12
# 2               DNK           NaN
# 3               DNK           NaN
# 4               NLD  2.585678e+11
# ...             ...           ...
# 290771          POL           NaN
# 290772          POL  5.450759e+11
# 290773          POL  5.450759e+11
# 290774          POL  1.743883e+11
# 290775          POL  1.986806e+11
#
# [290776 rows x 17 columns]

# %%
olympics_merge_gdp.isna().sum()
# Out:
# ID                   0
# Name                 0
# Sex                  0
# Age               9820
# Height           64997
# Weight           67851
# NOC                  0
# Games                0
# Year                 0
# Season               0
# City                 0
# Sport                0
# Event                0
# Medal                0
# Team              5960
# Country Code     62387
# GDP             135922
# dtype: int64

# %%
pop = pd.read_csv('../Data/WorldPopulation.csv', on_bad_lines='skip')

# 'Unnamed'로 시작하는 열 제거
pop = pop.loc[:, ~pop.columns.str.contains('^Unnamed')]

# %%
pop.drop(['Indicator Name', 'Indicator Code'], axis = 1, inplace = True)

pop = pd.melt(pop, id_vars = ['Country', 'Country Code'], var_name = 'Year', value_name = 'Population')

pop['Year'] = pd.to_numeric(pop['Year'])

pop.head()
# Out:
#        Country Country Code  Year  Population
# 0        Aruba          ABW  1960     54211.0
# 1  Afghanistan          AFG  1960   8996351.0
# 2       Angola          AGO  1960   5643182.0
# 3      Albania          ALB  1960   1608800.0
# 4      Andorra          AND  1960     13411.0

# %%
olympics_complete = olympics_merge_gdp.merge(pop,
                                            left_on = ['Country Code', 'Year'],
                                            right_on= ['Country Code', 'Year'],
                                            how = 'left')

olympics_complete.drop('Country', axis = 1, inplace = True)

olympics_complete.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight  NOC        Games  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0  CHN  1992 Summer
# 1   2                  A Lamusi   M  23.0   170.0    60.0  CHN  2012 Summer
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN  1920 Summer
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN  1900 Summer
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED  1988 Winter
#
#    Year  Season       City          Sport                             Event  \
# 0  1992  Summer  Barcelona     Basketball       Basketball Men's Basketball
# 1  2012  Summer     London           Judo      Judo Men's Extra-Lightweight
# 2  1920  Summer  Antwerpen       Football           Football Men's Football
# 3  1900  Summer      Paris     Tug-Of-War       Tug-Of-War Men's Tug-Of-War
# 4  1988  Winter    Calgary  Speed Skating  Speed Skating Women's 500 metres
#
#   Medal         Team Country Code           GDP    Population
# 0   DNW        China          CHN  4.269157e+11  1.164970e+09
# 1   DNW        China          CHN  8.560547e+12  1.350695e+09
# 2   DNW      Denmark          DNK           NaN           NaN
# 3  Gold      Denmark          DNK           NaN           NaN
# 4   DNW  Netherlands          NLD  2.585678e+11  1.476009e+07

# %%
olympics_complete.isnull().sum()
# Out:
# ID                   0
# Name                 0
# Sex                  0
# Age               9820
# Height           64997
# Weight           67851
# NOC                  0
# Games                0
# Year                 0
# Season               0
# City                 0
# Sport                0
# Event                0
# Medal                0
# Team              5960
# Country Code     62387
# GDP             135922
# Population      118757
# dtype: int64

# %%
Main_DF = olympics_complete.loc[(olympics_complete['Year'] > 1960) & (olympics_complete['Season'] == "Summer"), :]

Main_DF = Main_DF.reset_index()

# %%
Main_DF.isnull().sum()
# Out:
# index               0
# ID                  0
# Name                0
# Sex                 0
# Age               827
# Height           7042
# Weight           7308
# NOC                 0
# Games               0
# Year                0
# Season              0
# City                0
# Sport               0
# Event               0
# Medal               0
# Team             4662
# Country Code    37404
# GDP             49968
# Population      38564
# dtype: int64

# %%
Main_DF['Medal_Won'] = np.where(Main_DF.loc[:,'Medal'] == 'DNW', 0, 1)

# %%
identify_team_events = pd.pivot_table(Main_DF,
                                      index = ['Team', 'Year', 'Event'],
                                      columns = 'Medal',
                                      values = 'Medal_Won',
                                      aggfunc = 'sum',
                                     fill_value = 0).drop('DNW', axis = 1).reset_index()

identify_team_events = identify_team_events.loc[identify_team_events['Gold'] > 1, :]

team_sports = identify_team_events['Event'].unique()

team_sports
# Out:
# array(["Basketball Men's Basketball", "Football Men's Football",
#        "Cycling Men's Madison", "Hockey Men's Hockey",
#        'Sailing Mixed Multihull', 'Sailing Mixed 5.5 metres',
#        'Sailing Mixed Three Person Keelboat',
#        'Sailing Mixed Two Person Keelboat',
#        "Swimming Men's 4 x 100 metres Medley Relay",
#        "Cycling Men's Team Pursuit, 4,000 metres",
#        "Hockey Women's Hockey",
#        'Equestrianism Mixed Three-Day Event, Team',
#        "Rowing Men's Coxless Fours", "Rowing Men's Double Sculls",
#        "Rowing Women's Coxless Pairs", "Tennis Men's Doubles",
#        "Beach Volleyball Women's Beach Volleyball",
#        "Sailing Men's Two Person Dinghy",
#        "Sailing Women's Two Person Dinghy",
#        "Swimming Men's 4 x 100 metres Freestyle Relay",
#        "Swimming Men's 4 x 200 metres Freestyle Relay",
#        "Water Polo Women's Water Polo", "Rowing Men's Coxless Pairs",
#        "Swimming Women's 4 x 100 metres Freestyle Relay",
#        "Swimming Women's 4 x 100 metres Medley Relay",
#        "Swimming Women's 4 x 200 metres Freestyle Relay",
#        "Canoeing Men's Kayak Fours, 1,000 metres", "Sailing Men's Skiff",
#        "Rugby Sevens Women's Rugby Sevens",
#        "Athletics Women's 4 x 100 metres Relay",
#        "Athletics Men's 4 x 400 metres Relay",
#        "Canoeing Men's Canadian Doubles, 1,000 metres",
#        'Tennis Mixed Doubles', 'Sailing Mixed Two Person Dinghy',
#        "Volleyball Men's Volleyball",
#        "Beach Volleyball Men's Beach Volleyball",
#        "Sailing Men's Two Person Keelboat",
#        "Volleyball Women's Volleyball", "Sailing Women's Skiff",
#        "Rowing Women's Double Sculls",
#        'Equestrianism Mixed Jumping, Team',
#        "Canoeing Men's Kayak Doubles, 1,000 metres",
#        "Rowing Men's Coxed Eights", "Synchronized Swimming Women's Duet",
#        "Rowing Women's Coxed Eights", "Rowing Women's Coxless Fours",
#        "Athletics Men's 4 x 100 metres Relay",
#        "Table Tennis Men's Doubles", "Table Tennis Women's Doubles",
#        "Badminton Women's Doubles", 'Badminton Mixed Doubles',
#        "Diving Men's Synchronized Springboard",
#        "Diving Women's Synchronized Platform",
#        "Gymnastics Men's Team All-Around",
#        "Canoeing Men's Canadian Doubles, 500 metres",
#        "Diving Men's Synchronized Platform",
#        "Diving Women's Synchronized Springboard",
#        "Tennis Women's Doubles", "Gymnastics Women's Team All-Around",
#        "Rowing Women's Quadruple Sculls", "Table Tennis Men's Team",
#        "Table Tennis Women's Team", "Badminton Men's Doubles",
#        "Fencing Women's epee, Team", "Cycling Women's Team Sprint",
#        "Handball Men's Handball", "Water Polo Men's Water Polo",
#        "Baseball Men's Baseball",
#        'Sailing Mixed Two Person Heavyweight Dinghy',
#        "Handball Women's Handball",
#        "Rowing Men's Lightweight Coxless Fours", 'Sailing Mixed Skiff',
#        "Rowing Men's Lightweight Double Sculls",
#        "Rugby Sevens Men's Rugby Sevens",
#        "Cycling Men's Tandem Sprint, 2,000 metres",
#        "Fencing Men's Foil, Team", "Fencing Men's epee, Team",
#        "Fencing Women's Foil, Team",
#        "Canoeing Men's Canadian Doubles, Slalom",
#        "Cycling Men's Team Sprint", "Fencing Men's Sabre, Team",
#        "Athletics Men's Decathlon", "Athletics Women's 80 metres Hurdles",
#        "Canoeing Men's Canadian Singles, 1,000 metres",
#        "Canoeing Women's Kayak Doubles, 500 metres",
#        "Diving Women's Springboard", 'Equestrianism Mixed Dressage, Team',
#        "Rowing Men's Coxed Fours", 'Sailing Mixed One Person Dinghy',
#        "Athletics Men's 5,000 metres", "Athletics Women's High Jump",
#        "Athletics Women's Javelin Throw", "Athletics Women's Long Jump",
#        "Boxing Men's Featherweight", "Boxing Men's Light-Heavyweight",
#        "Canoeing Men's Kayak Doubles, 500 metres",
#        "Canoeing Women's Kayak Singles, 500 metres",
#        "Canoeing Women's Kayak Singles, Slalom",
#        "Cycling Men's 100 kilometres Team Time Trial",
#        "Cycling Men's Sprint",
#        "Cycling Women's Individual Pursuit, 3,000 metres",
#        'Equestrianism Mixed Dressage, Individual',
#        'Equestrianism Mixed Jumping, Individual',
#        "Rowing Men's Quadruple Sculls", "Rowing Men's Single Sculls",
#        "Shooting Men's Rapid-Fire Pistol, 25 metres",
#        "Shooting Men's Running Target, 10 metres",
#        "Swimming Women's 400 metres Freestyle",
#        "Weightlifting Men's Heavyweight II",
#        "Wrestling Men's Light-Heavyweight, Greco-Roman",
#        "Athletics Men's Discus Throw", "Athletics Women's Discus Throw",
#        "Athletics Women's Shot Put",
#        "Canoeing Men's Kayak Singles, Slalom",
#        "Canoeing Women's Kayak Fours, 500 metres",
#        "Gymnastics Men's Horizontal Bar", "Judo Men's Half-Lightweight",
#        "Shooting Men's Small-Bore Rifle, Prone, 50 metres",
#        "Athletics Men's 800 metres",
#        "Cycling Men's Individual Pursuit, 4,000 metres",
#        "Cycling Men's Road Race, Individual",
#        "Canoeing Men's Canadian Singles, 500 metres",
#        "Judo Women's Lightweight", "Rowing Women's Single Sculls",
#        "Trampolining Women's Individual",
#        "Cycling Women's Mountainbike, Cross-Country",
#        'Equestrianism Mixed Three-Day Event, Individual',
#        "Fencing Men's Foil, Individual",
#        "Fencing Women's epee, Individual", "Judo Men's Half-Middleweight",
#        "Modern Pentathlon Women's Individual",
#        "Swimming Women's 100 metres Freestyle",
#        "Swimming Women's 50 metres Freestyle",
#        "Triathlon Men's Olympic Distance",
#        "Weightlifting Men's Super-Heavyweight",
#        "Athletics Men's Javelin Throw", "Cycling Women's Sprint",
#        "Football Women's Football",
#        "Shooting Women's Small-Bore Rifle, Three Positions, 50 metres",
#        "Modern Pentathlon Men's Team", "Rowing Men's Coxed Pairs",
#        "Archery Men's Team", "Softball Women's Softball",
#        "Rowing Women's Lightweight Double Sculls",
#        "Gymnastics Women's Balance Beam", "Rowing Women's Coxed Fours",
#        "Rowing Women's Coxed Quadruple Sculls",
#        "Basketball Women's Basketball",
#        "Athletics Women's 4 x 400 metres Relay",
#        "Rhythmic Gymnastics Women's Group",
#        "Synchronized Swimming Women's Team",
#        "Canoeing Men's Kayak Doubles, 200 metres",
#        "Fencing Women's Sabre, Team", "Archery Women's Team",
#        "Sailing Women's Three Person Keelboat",
#        "Cycling Women's Team Pursuit",
#        "Swimming Men's 50 metres Freestyle"], dtype=object)

# %%
remove_sports = ["Gymnastics Women's Balance Beam", "Gymnastics Men's Horizontal Bar", 
                 "Swimming Women's 100 metres Freestyle", "Swimming Men's 50 metres Freestyle"]

team_sports = list(set(team_sports) - set(remove_sports))

# %%
team_event_mask = Main_DF['Event'].map(lambda x: x in team_sports)
single_event_mask = [not i for i in team_event_mask]


medal_mask = Main_DF['Medal_Won'] == 1

Main_DF['Team_Event'] = np.where(team_event_mask & medal_mask, 1, 0)


Main_DF['Single_Event'] = np.where(single_event_mask & medal_mask, 1, 0)


Main_DF['Event_Category'] = Main_DF['Single_Event'] + \
Main_DF['Team_Event']
# Out:
# C:\Users\KDT17\AppData\Local\Temp\ipykernel_2004\2091496342.py:10: FutureWarning: Logical ops (and, or, xor) between Pandas objects and dtype-less sequences (e.g. list, tuple) are deprecated and will raise in a future version. Wrap the object in a Series, Index, or np.array before operating instead.
#   Main_DF['Single_Event'] = np.where(single_event_mask & medal_mask, 1, 0)

# %%
medal_df = Main_DF.\
groupby(['Year', 'Team', 'Event', 'Medal'])[['Medal_Won', 'Event_Category']].agg('sum').reset_index()

medal_df['Medal_Won_Corrected'] = medal_df['Medal_Won']/medal_df['Event_Category']

# %%
# 가장 많은 메달 딴 나라 top 4개국
medal_df = medal_df.groupby(['Year','Team'])['Medal_Won_Corrected'].agg('sum').reset_index()

medal_pivot = pd.pivot_table(medal_df,
                     index = 'Team',
                     columns = 'Year',
                     values = 'Medal_Won_Corrected',
                     aggfunc = 'sum',
                     margins = True).sort_values('All', ascending = False)[1:5]

# print total medals won in the given period
medal_pivot.loc[:,'All']
# Out:
# Team
# USA        1387.0
# Russia     1298.0
# China       545.0
# Germany     429.0
# Name: All, dtype: float64

# %%
# Year와 City 열만 선택 후, 중복된 값을 제거
Main_DF[['Year', 'City']].drop_duplicates().sort_values('Year')
# Out:
#     Year            City
# 74  1964           Tokyo
# 11  1968     Mexico City
# 12  1972          Munich
# 37  1976        Montreal
# 70  1980          Moskva
# 10  1984     Los Angeles
# 13  1988           Seoul
# 0   1992       Barcelona
# 3   1996         Atlanta
# 2   2000          Sydney
# 9   2004          Athina
# 6   2008         Beijing
# 1   2012          London
# 7   2016  Rio de Janeiro

# %%
# 오타 수정
Main_DF['City'] = Main_DF['City'].replace(['Athina', 'Moskva'], ['Athens', 'Moscow'])

# %%
# 개최국 데이처 추가
city_to_country = {'Tokyo': 'Japan',
                  'Mexico City': 'Mexico',
                  'Munich': 'Germany',
                  'Montreal': 'Canada',
                  'Moscow': 'Russia',
                  'Los Angeles': 'USA',
                  'Seoul': 'South Korea',
                  'Barcelona': 'Spain',
                  'Atlanta': 'USA',
                  'Sydney': 'Australia',
                  'Athens': 'Greece',
                  'Beijing': 'China',
                  'London': 'UK',
                  'Rio de Janeiro' : 'Brazil'}


Main_DF['Country_Host'] = Main_DF['City'].map(city_to_country)

Main_DF.loc[:, ['Year', 'Country_Host']].drop_duplicates().sort_values('Year')
# Out:
#     Year Country_Host
# 74  1964        Japan
# 11  1968       Mexico
# 12  1972      Germany
# 37  1976       Canada
# 70  1980       Russia
# 10  1984          USA
# 13  1988  South Korea
# 0   1992        Spain
# 3   1996          USA
# 2   2000    Australia
# 9   2004       Greece
# 6   2008        China
# 1   2012           UK
# 7   2016       Brazil

# %%
# 국가별 참가인원 계산
year_team_gender = Main_DF.loc[:,['Year','Team', 'Name', 'Sex']].drop_duplicates()

year_team_gender_count = pd.pivot_table(year_team_gender,
                                        index = ['Year', 'Team'],
                                        columns = 'Sex',
                                        aggfunc = 'count').reset_index()


year_team_gender_count.columns = year_team_gender_count.columns.get_level_values(0)


year_team_gender_count.columns = ['Year', 'Team', 'Female_Athletes', 'Male_Athletes']
year_team_gender_count = year_team_gender_count.fillna(0)


year_team_gender_count['Total_Athletes'] = year_team_gender_count['Female_Athletes'] + \
year_team_gender_count['Male_Athletes']

year_team_count = year_team_gender_count.loc[:, ['Year', 'Team','Total_Athletes']]
year_team_count.head()
# Out:
#    Year         Team  Total_Athletes
# 0  1964  Afghanistan             8.0
# 1  1964      Algeria             1.0
# 2  1964    Argentina           102.0
# 3  1964    Australia           243.0
# 4  1964      Austria            56.0

# %%
year_team_gdp = Main_DF.loc[:, ['Year', 'Team', 'GDP']].drop_duplicates()

medal_gdp = medal_df.merge(year_team_gdp,
                                   left_on = ['Year', 'Team'],
                                   right_on = ['Year', 'Team'],
                                   how = 'left')

# %%
r = medal_gdp['Medal_Won_Corrected'] > 0
correlation = medal_gdp.loc[r, ['GDP', 'Medal_Won_Corrected']].corr()['Medal_Won_Corrected'][0]
print(correlation)
# Out:
# 0.6321293165512418
# C:\Users\KDT17\AppData\Local\Temp\ipykernel_2004\2512689612.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   correlation = medal_gdp.loc[r, ['GDP', 'Medal_Won_Corrected']].corr()['Medal_Won_Corrected'][0]

# %%
medal_gdp.head()
# Out:
#    Year         Team  Medal_Won_Corrected           GDP
# 0  1964  Afghanistan                  0.0  8.000000e+08
# 1  1964      Algeria                  0.0  2.909352e+09
# 2  1964    Argentina                  1.0  2.560525e+10
# 3  1964    Australia                 18.0  2.378766e+10
# 4  1964      Austria                  0.0  9.169984e+09

# %%
year_team_pop = Main_DF.loc[:, ['Year', 'Team', 'Population']].drop_duplicates()
year_team_pop.head()
# Out:
#    Year     Team    Population
# 0  1992    China  1.164970e+09
# 1  2012    China  1.350695e+09
# 2  2000  Finland  5.176209e+06
# 3  1996  Finland  5.124573e+06
# 6  2008   Norway  4.768212e+06

# %%
medal_gdp_population = medal_gdp.merge(year_team_pop,
                                            left_on = ['Year', 'Team'],
                                            right_on = ['Year', 'Team'],
                                            how = 'left')

medal_gdp_pop_TA = medal_gdp_population.merge(year_team_count,
                                                     left_on = ['Year', 'Team'],
                                                     right_on = ['Year', 'Team'],
                                                     how = 'left')
medal_gdp_pop_TA.head()
# Out:
#    Year         Team  Medal_Won_Corrected           GDP  Population  \
# 0  1964  Afghanistan                  0.0  8.000000e+08   9731361.0
# 1  1964      Algeria                  0.0  2.909352e+09  12295970.0
# 2  1964    Argentina                  1.0  2.560525e+10  21953929.0
# 3  1964    Australia                 18.0  2.378766e+10  11167000.0
# 4  1964      Austria                  0.0  9.169984e+09   7223801.0
#
#    Total_Athletes
# 0             8.0
# 1             1.0
# 2           102.0
# 3           243.0
# 4            56.0

# %%
year_host = Main_DF.loc[:, ['Year', 'Country_Host']].drop_duplicates()

Analytical_data = medal_gdp_pop_TA.merge(year_host,
                              left_on = 'Year',
                              right_on = 'Year',
                              how = 'left')

Analytical_data.head()
# Out:
#    Year         Team  Medal_Won_Corrected           GDP  Population  \
# 0  1964  Afghanistan                  0.0  8.000000e+08   9731361.0
# 1  1964      Algeria                  0.0  2.909352e+09  12295970.0
# 2  1964    Argentina                  1.0  2.560525e+10  21953929.0
# 3  1964    Australia                 18.0  2.378766e+10  11167000.0
# 4  1964      Austria                  0.0  9.169984e+09   7223801.0
#
#    Total_Athletes Country_Host
# 0             8.0        Japan
# 1             1.0        Japan
# 2           102.0        Japan
# 3           243.0        Japan
# 4            56.0        Japan

# %%
import statsmodels.api as sm
from patsy import dmatrices
from sklearn import metrics

# %%
# 독립변수
# 문자형 데이터 -> 범주형 데이터로 변환
Analytical_data['Home_adv'] = np.where(Analytical_data['Country_Host'] == Analytical_data['Team'], 1, 0)

# %%
Analytical_data.info
# Out:
# <bound method DataFrame.info of       Year                     Team  Medal_Won_Corrected           GDP  \
# 0     1964              Afghanistan                  0.0  8.000000e+08
# 1     1964                  Algeria                  0.0  2.909352e+09
# 2     1964                Argentina                  1.0  2.560525e+10
# 3     1964                Australia                 18.0  2.378766e+10
# 4     1964                  Austria                  0.0  9.169984e+09
# ...    ...                      ...                  ...           ...
# 2155  2016  Virgin Islands, British                  0.0           NaN
# 2156  2016       Virgin Islands, US                  0.0           NaN
# 2157  2016                    Yemen                  0.0           NaN
# 2158  2016                   Zambia                  0.0  2.106399e+10
# 2159  2016                 Zimbabwe                  0.0  1.661996e+10
#
#       Population  Total_Athletes Country_Host  Home_adv
# 0      9731361.0             8.0        Japan         0
# 1     12295970.0             1.0        Japan         0
# 2     21953929.0           102.0        Japan         0
# 3     11167000.0           243.0        Japan         0
# 4      7223801.0            56.0        Japan         0
# ...          ...             ...          ...       ...
# 2155         NaN             4.0       Brazil         0
# 2156         NaN             7.0       Brazil         0
# 2157         NaN             3.0       Brazil         0
# 2158  16591390.0             7.0       Brazil         0
# 2159  16150362.0            30.0       Brazil         0
#
# [2160 rows x 8 columns]>

# %%
# 결측치 확인
Analytical_data.isna().sum()
# Out:
# Year                     0
# Team                     0
# Medal_Won_Corrected      0
# GDP                    510
# Population             346
# Total_Athletes           0
# Country_Host             0
# Home_adv                 0
# dtype: int64

# %%
# 결측치 처리
Analytical_data.dropna(how = 'any', inplace = True)

# %%
# 결측치 확인
Analytical_data.isna().sum()
# Out:
# Year                   0
# Team                   0
# Medal_Won_Corrected    0
# GDP                    0
# Population             0
# Total_Athletes         0
# Country_Host           0
# Home_adv               0
# dtype: int64

# %%
# 독립변수( population 과 GDP) 분포 확인 -> 히스토그램

fig, (ax1, ax2) = plt.subplots(nrows = 1,
                          ncols = 2,
                          figsize = (14,5))

Analytical_data['GDP'].hist(bins = 15, ax = ax1)
ax1.set_title('GDP 분포')

Analytical_data['Population'].hist(bins = 15, ax = ax2)
ax2.set_title('국가별 인구 분포')
# Out:
# Text(0.5, 1.0, '국가별 인구 분포')

# %%
# 한쪽으로 치우져있는 그래프 -> log변환 수행
# 이유 : 선형모델에 맞도록 정규화를 시켜야 정확한 예측 가능

# %%
import math

# log변환
Analytical_data['Log_GDP'] = np.log(Analytical_data['GDP'])
Analytical_data['Log_Population'] = np.log(Analytical_data['Population'])

# %%
# 다시한번 그래프를 그려 이전에 그렸던 그래프와 비교
# 변환한 데이터가 정규분포에 조금이라도 같아졌는지 확인
fig, (ax1, ax2) = plt.subplots(nrows = 1,
                          ncols = 2,
                          figsize = (14,5))

Analytical_data['Log_GDP'].hist(bins = 15, ax = ax1)
ax1.set_title('GDP 분포(Log_GDP)')

Analytical_data['Log_Population'].hist(bins = 15, ax = ax2)
ax2.set_title('국가별 인구 분포(Log_Population)')
# Out:
# Text(0.5, 1.0, '국가별 인구 분포(Log_Population)')

# %%
# OLS분석 
y, X = dmatrices('Medal_Won_Corrected ~ Log_GDP + Log_Population + Total_Athletes + Home_adv', 
                data = Analytical_data,
                return_type = 'dataframe')

model = sm.OLS(y, X)
ols_results = model.fit()

ols_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     Medal_Won_Corrected   R-squared:                       0.780
# Model:                             OLS   Adj. R-squared:                  0.779
# Method:                  Least Squares   F-statistic:                     1454.
# Date:                 Tue, 04 Mar 2025   Prob (F-statistic):               0.00
# Time:                         12:41:47   Log-Likelihood:                -4665.4
# No. Observations:                 1646   AIC:                             9341.
# Df Residuals:                     1641   BIC:                             9368.
# Df Model:                            4
# Covariance Type:             nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          7.2504      1.317      5.503      0.000       4.666       9.834
# Log_GDP           -0.5263      0.075     -7.048      0.000      -0.673      -0.380
# Log_Population     0.2100      0.070      3.010      0.003       0.073       0.347
# Total_Athletes     0.1053      0.002     59.445      0.000       0.102       0.109
# Home_adv         -10.5928      1.576     -6.721      0.000     -13.684      -7.501
# ==============================================================================
# Omnibus:                     1267.641   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            92147.468
# Skew:                           2.990   Prob(JB):                         0.00
# Kurtosis:                      39.164   Cond. No.                     1.54e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.54e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# 회귀 계수 가져오기
intercept = ols_results.params['Intercept']  # 절편
coeff_Log_GDP = ols_results.params['Log_GDP']
coeff_Log_Population = ols_results.params['Log_Population']
coeff_Total_Athletes = ols_results.params['Total_Athletes']
coeff_Home_adv = ols_results.params['Home_adv']

# 회귀식 출력
regression_equation = f"""
회귀식:
Y = {intercept:.2f} 
    + ({coeff_Log_GDP:.4f} * Log_GDP) 
    + ({coeff_Log_Population:.4f} * Log_Population) 
    + ({coeff_Total_Athletes:.4f} * Total_Athletes) 
    + ({coeff_Home_adv:.4f} * Home_adv)
"""

print(regression_equation)
# Out:
# 회귀식:
# Y = 7.25
#     + (-0.5263 * Log_GDP)
#     + (0.2100 * Log_Population)
#     + (0.1053 * Total_Athletes)
#     + (-10.5928 * Home_adv)

# %%
# 변수 값 (예시)
gdp = 1_720_000  # GDP (백만 달러)
population = 51_600_000  # 인구수
athletes = 143  # 참가 인원
host_country = 0  # 개최국 여부 (0: 비개최국)

# 로그 변환 적용
log_gdp = np.log(gdp)
log_population = np.log(population)

# 회귀식 계산 (올바른 로그 적용)
predicted_medals = (
    12.5302 +
    (-0.8136 * log_gdp) +
    (0.2566 * log_population) +
    (0.1225 * athletes) +
    (-12.3798 * host_country)
)

# 예측된 메달 갯수 출력
print(f'2024년 파리 올림픽 대한민국 메달 갯수 예측: {predicted_medals:.2f}개')
# Out:
# 2024년 파리 올림픽 대한민국 메달 갯수 예측: 22.92개

# %%
print(Analytical_data['Medal_Won_Corrected'].mean())
print(Analytical_data['Medal_Won_Corrected'].var())
# Out:
# 3.487849331713244
# 77.1034996879229

# %%
# 2.  Negative Binomial 회귀
# 분산이 평균보다 클 때(과대산포일때)사용
# mean:3.82 < var: 115.27

X = Analytical_data[['Log_GDP', 'Total_Athletes', 'Log_Population', 'Home_adv' ]]
X = sm.add_constant(X)  # 절편 추가
y = Analytical_data['Medal_Won_Corrected']

nb_model = sm.NegativeBinomial(y, X)
nb_results = nb_model.fit()
print(nb_results.summary())
# Out:
#          Current function value: 1.510138
#          Iterations: 35
#          Function evaluations: 39
#          Gradient evaluations: 39
#                       NegativeBinomial Regression Results
# ===============================================================================
# Dep. Variable:     Medal_Won_Corrected   No. Observations:                 1646
# Model:                NegativeBinomial   Df Residuals:                     1641
# Method:                            MLE   Df Model:                            4
# Date:                 Tue, 04 Mar 2025   Pseudo R-squ.:                  0.1908
# Time:                         12:41:47   Log-Likelihood:                -2485.7
# converged:                       False   LL-Null:                       -3071.9
# Covariance Type:             nonrobust   LLR p-value:                1.503e-252
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -7.2671      0.607    -11.971      0.000      -8.457      -6.077
# Log_GDP            0.2153      0.030      7.286      0.000       0.157       0.273
# Total_Athletes     0.0146      0.001     19.164      0.000       0.013       0.016
# Log_Population     0.0978      0.031      3.174      0.002       0.037       0.158
# Home_adv          -2.6491      0.475     -5.572      0.000      -3.581      -1.717
# alpha              1.3212      0.093     14.225      0.000       1.139       1.503
# ==================================================================================
# c:\Users\KDT17\anaconda3\envs\bigdata\Lib\site-packages\scipy\optimize\_optimize.py:1313: OptimizeWarning: Maximum number of iterations has been exceeded.
#   res = _minimize_bfgs(f, x0, args, fprime, callback=callback, **opts)
# c:\Users\KDT17\anaconda3\envs\bigdata\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
## 모델 적합도 확인 -> AIC값이 낮을수록 모델이 더 적합함

print("OLS AIC:", ols_results.aic)
print("Negative Binomial AIC:", nb_results.aic)

if ols_results.aic < nb_results.aic:
    print("OLS 모델이 더 적합합니다.")
else:
    print("Negative Binomial 모델이 더 적합합니다.")
# Out:
# OLS AIC: 9340.730315162129
# Negative Binomial AIC: 4983.375818975135
# Negative Binomial 모델이 더 적합합니다.

# %%
y_predicted = ols_results.predict(X)
np.sqrt(metrics.mean_squared_error(y, y_predicted))
# Out:
# np.float64(10.045592026131775)

# %%
y_predicted = nb_results.predict(X)
np.sqrt(metrics.mean_squared_error(y, y_predicted))
# Out:
# np.float64(116.19986274659372)

# %%
Analytical_data
# Out:
#       Year         Team  Medal_Won_Corrected           GDP  Population  \
# 0     1964  Afghanistan                  0.0  8.000000e+08   9731361.0
# 1     1964      Algeria                  0.0  2.909352e+09  12295970.0
# 2     1964    Argentina                  1.0  2.560525e+10  21953929.0
# 3     1964    Australia                 18.0  2.378766e+10  11167000.0
# 4     1964      Austria                  0.0  9.169984e+09   7223801.0
# ...    ...          ...                  ...           ...         ...
# 2151  2016   Uzbekistan                 13.0  6.722034e+10  31848200.0
# 2152  2016      Vanuatu                  0.0  7.735029e+08    270402.0
# 2154  2016      Vietnam                  2.0  2.052762e+11  92701100.0
# 2158  2016       Zambia                  0.0  2.106399e+10  16591390.0
# 2159  2016     Zimbabwe                  0.0  1.661996e+10  16150362.0
#
#       Total_Athletes Country_Host  Home_adv    Log_GDP  Log_Population
# 0                8.0        Japan         0  20.500122       16.090864
# 1                1.0        Japan         0  21.791196       16.324782
# 2              102.0        Japan         0  23.966063       16.904457
# 3              243.0        Japan         0  23.892433       16.228474
# 4               56.0        Japan         0  22.939201       15.792892
# ...              ...          ...       ...        ...             ...
# 2151            70.0       Brazil         0  24.931242       17.276491
# 2152             4.0       Brazil         0  20.466440       12.507665
# 2154            22.0       Brazil         0  26.047622       18.344891
# 2158             7.0       Brazil         0  23.770831       16.624394
# 2159            30.0       Brazil         0  23.533870       16.597453
#
# [1646 rows x 10 columns]

# %%
GDP_Veiw_Data = Analytical_data[['Year','Team','GDP','Medal_Won_Corrected','Country_Host']].sort_values('GDP', ascending=False)

# %%
# 2016, 2012 , 2008
# 매달 평균 , GDP 평균

GDP_Veiw_Data2016   =GDP_Veiw_Data[GDP_Veiw_Data['Year'] == 2016].sort_values('GDP', ascending=False)
GDP_Veiw_Data2012   =GDP_Veiw_Data[GDP_Veiw_Data['Year'] == 2012].sort_values('GDP', ascending=False)
GDP_Veiw_Data2008   =GDP_Veiw_Data[GDP_Veiw_Data['Year'] == 2008].sort_values('GDP', ascending=False)

# %%
GDP_Veiw_Data[['GDP','Medal_Won_Corrected']].corr()
# Out:
#                           GDP  Medal_Won_Corrected
# GDP                  1.000000             0.662516
# Medal_Won_Corrected  0.662516             1.000000

# %%
# x 축 GDP
# Y 축 총 매달갯수
x = GDP_Veiw_Data['GDP']
y = GDP_Veiw_Data['Medal_Won_Corrected']
plt.scatter(x,y, alpha=0.2, color='b')

# 선형 회귀선 계산 # 1차 다항식 (직선) 피팅
slope, intercept = np.polyfit(x,y,1)


# 회쉬선 추가
plt.plot(x,slope*x + intercept, color='red',linewidth=2, label='Regression Line')

# 상관계수 계산
a = GDP_Veiw_Data[['GDP','Medal_Won_Corrected']].corr()

# 그래프 제목 추가
plt.title(f'GDP & Total_Medals 상관계수 {a.iloc[0,1]:.2f}')

plt.xlabel('Country GDP')
plt.ylabel('Number of Medals')
plt.show()

# %%
plt.scatter(GDP_Veiw_Data2016.head(10)['GDP'], GDP_Veiw_Data2016.head(10)['Medal_Won_Corrected'], 
            alpha=0.5, color='r', edgecolors='k', label="2016")
plt.scatter(GDP_Veiw_Data2012.head(10)['GDP'], GDP_Veiw_Data2012.head(10)['Medal_Won_Corrected'], 
            alpha=0.5, color='g', edgecolors='k', label="2012")
plt.scatter(GDP_Veiw_Data2008.head(10)['GDP'], GDP_Veiw_Data2008.head(10)['Medal_Won_Corrected'], 
            alpha=0.5, color='b', edgecolors='k', label="2008")



# 2016년 회귀선 추가 
slope_2016, intercept_2016 = np.polyfit(GDP_Veiw_Data2016.head(10)['GDP'], GDP_Veiw_Data2016.head(10)['Medal_Won_Corrected'], 1)
plt.plot(GDP_Veiw_Data2016.head(10)['GDP'], slope_2016 * GDP_Veiw_Data2016.head(10)['GDP'] + intercept_2016, color='red', linewidth=2)

# 2012년 회귀선 추가
slope_2012, intercept_2012 = np.polyfit(GDP_Veiw_Data2012.head(10)['GDP'], GDP_Veiw_Data2012.head(10)['Medal_Won_Corrected'], 1)
plt.plot(GDP_Veiw_Data2012.head(10)['GDP'], slope_2012 * GDP_Veiw_Data2012.head(10)['GDP'] + intercept_2012, color='green', linewidth=2)

# 2008년 회귀선 추가
slope_2008, intercept_2008 = np.polyfit(GDP_Veiw_Data2008.head(10)['GDP'], GDP_Veiw_Data2008.head(10)['Medal_Won_Corrected'], 1)
plt.plot(GDP_Veiw_Data2008.head(10)['GDP'], slope_2008 * GDP_Veiw_Data2008.head(10)['GDP'] + intercept_2008, color='blue', linewidth=2)




a1 = GDP_Veiw_Data2016[['GDP','Medal_Won_Corrected']].head(10).corr()
print(a1)

a2 = GDP_Veiw_Data2012[['GDP','Medal_Won_Corrected']].head(10).corr()
print(a2)

a3 = GDP_Veiw_Data2008[['GDP','Medal_Won_Corrected']].head(10).corr()
print(a3)


# X축과 Y축 라벨 추가
plt.xlabel("Country GDP")
plt.ylabel("Number of Medals")

# 그래프 제목 추가
plt.title("Top 10 GDP vs. Medal Count (2008, 2012, 2016)")

# 범례 추가
plt.legend()

# 그래프 출력
plt.show()
# Out:
#                         GDP  Medal_Won_Corrected
# GDP                  1.0000               0.8213
# Medal_Won_Corrected  0.8213               1.0000
#                           GDP  Medal_Won_Corrected
# GDP                  1.000000             0.858495
# Medal_Won_Corrected  0.858495             1.000000
#                           GDP  Medal_Won_Corrected
# GDP                  1.000000             0.714649
# Medal_Won_Corrected  0.714649             1.000000

# %%
# GDP가 높은 국가 상위 5개 선택
top5_gdp = GDP_Veiw_Data2016.sort_values('GDP', ascending=False).head(5)

# X축 (국가 이름)
x = top5_gdp['Team']
# Y축 (GDP - Bar 그래프용)
y_gdp = top5_gdp['GDP']
# Y축 (총 메달 획득 수 - 산점도용)
y_medals = top5_gdp['Medal_Won_Corrected']



# 그래프 크기 설정
fig, ax1 = plt.subplots(figsize=(8, 5))

# Bar 그래프 (GDP)
ax1.bar(x, y_gdp, color='#02fd80', alpha=0.7, label="GDP")
ax1.set_xlabel("Country")
ax1.set_ylabel("GDP", color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# 두 번째 Y축 설정 (메달 개수)
ax2 = ax1.twinx()  # 새로운 Y축 추가
ax2.scatter(x, y_medals, color='red', marker='*', s=200, label="Total Medals")
ax2.set_ylabel("Total Medals", color='red')
ax2.tick_params(axis='y', labelcolor='red')

# 그래프 제목 및 범례 추가
plt.title("Top 5 GDP Countries: GDP vs. Total Medals (2016)")

handles1, labels1 = ax1.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()
plt.legend(handles1 + handles2, labels1 + labels2, loc="upper right")
# 그래프 출력
plt.show()

# %%
# GDP가 높은 국가 상위 5개 선택
top5_gdp = GDP_Veiw_Data2012.sort_values('GDP', ascending=False).head(5)

# X축 (국가 이름)
x = top5_gdp['Team']
# Y축 (GDP - Bar 그래프용)
y_gdp = top5_gdp['GDP']
# Y축 (총 메달 획득 수 - 산점도용)
y_medals = top5_gdp['Medal_Won_Corrected']



# 그래프 크기 설정
fig, ax1 = plt.subplots(figsize=(8, 5))

# Bar 그래프 (GDP)
ax1.bar(x, y_gdp, color='lightskyblue',edgecolor='black', hatch='\\', alpha=0.7, label="GDP")
ax1.set_xlabel("Country")
ax1.set_ylabel("GDP", color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# 두 번째 Y축 설정 (메달 개수)
ax2 = ax1.twinx()  # 새로운 Y축 추가
ax2.scatter(x, y_medals, color='red', marker='*', s=200, label="Total Medals")
ax2.set_ylabel("Total Medals", color='red')
ax2.tick_params(axis='y', labelcolor='red')

# 그래프 제목 및 범례 추가
plt.title("Top 5 GDP Countries: GDP vs. Total Medals (2012)")
handles1, labels1 = ax1.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()
plt.legend(handles1 + handles2, labels1 + labels2, loc="upper right")
# 그래프 출력
plt.show()

# %%
# GDP가 높은 국가 상위 5개 선택
top5_gdp = GDP_Veiw_Data2008.sort_values('GDP', ascending=False).head(5)

# X축 (국가 이름)
x = top5_gdp['Team']
# Y축 (GDP - Bar 그래프용)
y_gdp = top5_gdp['GDP']
# Y축 (총 메달 획득 수 - 산점도용)
y_medals = top5_gdp['Medal_Won_Corrected']

# 그래프 크기 설정
fig, ax1 = plt.subplots(figsize=(8, 5))

# Bar 그래프 (GDP)
ax1.bar(x, y_gdp, color='aquamarine', edgecolor='black', hatch='\\', alpha=0.7, label="GDP")
ax1.set_xlabel("Country")
ax1.set_ylabel("GDP (in Trillions)", color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# 두 번째 Y축 설정 (메달 개수)
ax2 = ax1.twinx()  # 새로운 Y축 추가
ax2.scatter(x, y_medals, color='red', marker='*', s=200, label="Total Medals")
ax2.set_ylabel("Total Medals", color='red')
ax2.tick_params(axis='y', labelcolor='red')

# 그래프 제목 추가
plt.title("Top 5 GDP Countries: GDP vs. Total Medals (2008)")

# 범례 정보 가져와서 합치기
handles1, labels1 = ax1.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()
plt.legend(handles1 + handles2, labels1 + labels2, loc="upper right")

# 그래프 출력
plt.show()
